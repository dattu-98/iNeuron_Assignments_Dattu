# %% [markdown]
# 1) In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?

# %%
#pip install the module and then import it
import PyPDF2

# %%
#Both PdfFileReader() and PdfFileWriter() are opened in "Read Binary mode" i.e. 'rb'

# %% [markdown]
# 2)  From a PdfFileReader object, how do you get a Page object for page 5?

# %% [markdown]
# # Reading text from PDF's

# %%
import os

# %%
# %pwd
# Out:
# 'C:\\Users\\User\\iNeuron Full Stack Data Science\\Assignments\\Python_Basic'

# %%
os.chdir('F:\Data Science')

# %%
FSDS_curriculum=open('PDD_Assignment_Report_Modular_Shoes_2020PMT5387.pdf','rb')
FSDS_reader=PyPDF2.PdfFileReader(FSDS_curriculum)

# %%
FSDS_page=FSDS_reader.getPage(5)

# %%
print(FSDS_page.extractText())
# Out:
# 6
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Type of Modular Shoes you
# need?
#
# Purpose of modular shoes?
#
# More specific category of shoes
# you need:

# %% [markdown]
# 3) What PdfFileReader variable stores the number of pages in the PDF document?

# %%
FSDS_no_of_pages=FSDS_reader.numPages
print(FSDS_no_of_pages)
# Out:
# 18

# %% [markdown]
# 4)  If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?

# %%
#First we must decrypt("password") the file by passing the password as string in that.
#FSDS_reader.decrypt("swordfish")

# %% [markdown]
# 5) What methods do you use to rotate a page?

# %%
#with the help of rotateClockwise() and rotateCounterClockwise() we can rotate the page
FSDS_page=FSDS_reader.getPage(1)

# %%
FSDS_page.rotateClockwise(90)
# Out:
# {'/Type': '/Page',
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 18,
#   '/Kids': [IndirectObject(3, 0),
#    IndirectObject(19, 0),
#    IndirectObject(29, 0),
#    IndirectObject(37, 0),
#    IndirectObject(44, 0),
#    IndirectObject(59, 0),
#    IndirectObject(64, 0),
#    IndirectObject(71, 0),
#    IndirectObject(81, 0),
#    IndirectObject(88, 0),
#    IndirectObject(92, 0),
#    IndirectObject(97, 0),
#    IndirectObject(101, 0),
#    IndirectObject(104, 0),
#    IndirectObject(107, 0),
#    IndirectObject(109, 0),
#    IndirectObject(114, 0),
#    IndirectObject(116, 0)]},
#  '/Resources': {'/Font': {'/F1': {'/Type': '/Font',
#     '/Subtype': '/TrueType',
#     '/Name': '/F1',
#     '/BaseFont': '/ArialMT',
#     '/Encoding': '/WinAnsiEncoding',
#     '/FontDescriptor': {'/Type': '/FontDescriptor',
#      '/FontName': '/ArialMT',
#      '/Flags': 32,
#      '/ItalicAngle': 0,
#      '/Ascent': 905,
#      '/Descent': -210,
#      '/CapHeight': 728,
# ...

# %%
FSDS_page.rotateCounterClockwise(90)
# Out:
# {'/Type': '/Page',
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 18,
#   '/Kids': [IndirectObject(3, 0),
#    IndirectObject(19, 0),
#    IndirectObject(29, 0),
#    IndirectObject(37, 0),
#    IndirectObject(44, 0),
#    IndirectObject(59, 0),
#    IndirectObject(64, 0),
#    IndirectObject(71, 0),
#    IndirectObject(81, 0),
#    IndirectObject(88, 0),
#    IndirectObject(92, 0),
#    IndirectObject(97, 0),
#    IndirectObject(101, 0),
#    IndirectObject(104, 0),
#    IndirectObject(107, 0),
#    IndirectObject(109, 0),
#    IndirectObject(114, 0),
#    IndirectObject(116, 0)]},
#  '/Resources': {'/Font': {'/F1': {'/Type': '/Font',
#     '/Subtype': '/TrueType',
#     '/Name': '/F1',
#     '/BaseFont': '/ArialMT',
#     '/Encoding': '/WinAnsiEncoding',
#     '/FontDescriptor': {'/Type': '/FontDescriptor',
#      '/FontName': '/ArialMT',
#      '/Flags': 32,
#      '/ItalicAngle': 0,
#      '/Ascent': 905,
#      '/Descent': -210,
#      '/CapHeight': 728,
# ...

# %% [markdown]
# 6) What is the difference between a Run object and a Paragraph object?

# %%
#Paragraph objects are considered as whenever the users press ENTER or RETURN while typing in the Word document
#Run is a low level object where the Each Sentence,word are considered as RUN
#With the help of docx we can read Word Documents

# %% [markdown]
# 7)  How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc_file?

# %%
! pip install Python-Docx
# Out:
# ...
#   Created wheel for Python-Docx: filename=python_docx-0.8.10-py3-none-any.whl size=184495 sha256=c3b90752ad9cc76f5164a6c01a56dd60188f74801835d03de9062b20399252d5
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\97\4c\2e\68066cbf12b9b2e66403da8982aaf4f656d9f5cb5dc3179e82
# Successfully built Python-Docx
# ...

# %%
import docx

# %%
doc_file=docx.Document('PDD_Assignment_2020PMT5387.docx')

# %%
len(doc_file.paragraphs)
# Out:
# 478

# %%
doc_file.paragraphs[1].text
# Out:
# 'MODULAR SHOES'

# %%
doc_file.paragraphs[3].text
# Out:
# 'Product Development process is generally classified in six phases. They are:'

# %% [markdown]
# 8) What type of object has bold, underline, italic, strike, and outline variables?

# %%
#Run object has all the above variables i.e. Bold,Underline,italic,Strike,outline

# %% [markdown]
# 9) What is the difference between False, True, and None for the bold variable?

# %%
#False-> The attribute is disabled
#True-> The attribute is enabled
#None-> The styling is set to default

# %% [markdown]
# 10)  How do you create a Document object for a new Word document?

# %%
new_file=docx.Document()

# %%
new_file.add_heading("Using docx module")

# %%
new_file.add_paragraph("This is an automated way of creating things using the docx module in python")

# %%
new_file.save("python_doxc.docx")

# %% [markdown]
# 11) How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named new_file?

# %%
new_file=docx.Document("python_doxc.docx")

# %%
new_file.add_paragraph("Hello, there!")

# %%
new_file.save("python_doxc.docx")

# %% [markdown]
# 12) What integers represent the levels of headings available in Word documents?

# %%
#Numbers 0 to 4 indicate the different sizes of text in the word document with 0 being he largest text among those
